# %% [markdown]
# # BizLens v2.3.4 - Chi-Square Test

# %% [markdown]
# <a href="https://colab.research.google.com/github/solutiongate-learn/bizlens/blob/main/notebooks/New_ChiSquareTest.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Setup: BizLens in Google Colab
# This cell installs dependencies and prepares the environment

# Install BizLens
# !pip install bizlens networkx -q

# Check if running in Colab
try:
    from google.colab import drive
    drive.mount('/content/drive')
    IN_COLAB = True
except:
    IN_COLAB = False

# Test import
import bizlens as bl
print("✓ BizLens loaded successfully")

# %%
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", "bizlens"])
print("✅ BizLens v2.2.15 ready!")

# %% [markdown]
# ## 🎨 Chart & Display Settings

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# ── Global Chart Theme ────────────────────────────────────────────────────
plt.rcParams.update({
    # Fonts
    'font.family':        'DejaVu Sans',
    'font.size':          12,
    'axes.titlesize':     15,
    'axes.titleweight':   'bold',
    'axes.titlepad':      12,
    'axes.labelsize':     12,
    'axes.labelweight':   'bold',
    'xtick.labelsize':    10,
    'ytick.labelsize':    10,
    'legend.fontsize':    11,
    'legend.title_fontsize': 12,

    # Figure
    'figure.dpi':         130,
    'figure.figsize':     [10, 6],
    'figure.facecolor':   'white',
    'axes.facecolor':     '#FAFAFA',

    # Grid & Spines
    'axes.grid':          True,
    'grid.alpha':         0.4,
    'grid.linestyle':     '--',
    'grid.color':         '#CCCCCC',
    'axes.spines.top':    False,
    'axes.spines.right':  False,
    'axes.edgecolor':     '#888888',

    # Colour cycle — professional palette
    'axes.prop_cycle': mpl.cycler('color', [
        '#2196F3',   # blue
        '#FF5722',   # deep orange
        '#4CAF50',   # green
        '#9C27B0',   # purple
        '#FF9800',   # amber
        '#00BCD4',   # cyan
        '#F44336',   # red
        '#607D8B',   # blue-grey
    ]),

    # Lines & Markers
    'lines.linewidth':    2.2,
    'lines.markersize':   6,
    'patch.linewidth':    0.5,

    # Tight layout
    'figure.autolayout': True,
})
print("✅ Chart theme applied — all plots will use professional styling")

# %%
import bizlens as bl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="husl", font_scale=1.1)

# %% [markdown]
# ## Analysis

# %%
# Add analysis here
print("Ready for analysis")
